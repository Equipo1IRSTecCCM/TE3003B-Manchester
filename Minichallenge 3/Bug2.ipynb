# %% [markdown]
# # Bug2
# ## Equipo 3

# %% [markdown]
# Primero se importan las librerias necesarias.

# %%
import rospy
import numpy as np
from geometry_msgs.msg import Twist, PoseStamped
from nav_msgs.msg import Odometry
from sensor_msgs.msg import LaserScan
from smach import State, StateMachine
import smach_ros
from tf.transformations import euler_from_quaternion

# %% [markdown]
# Controlador simple

# %%
class ControlPID:
    def __init__(self, rate, kp = 1, ki = 0, kd = 0):
        self.rate = rate
        self.kp = kp
        self.ki = ki
        self.kd = kd
        self.i = 0
        self.ea = 0
        self.pred = 0

    def update(self, current, goal):
        ep = goal - current
        self.i = self.i + self.ki*ep*self.rate
        ed = (ep - self.ea)/self.rate
        self.ea = ep
        self.pred = current + ep*self.kp + self.i + ed*self.kd

# %% [markdown]
# Luego se declaran variables globales.

# %%
pos = Twist()
c_vel = Twist()
pub = rospy.Publisher('/cmd_vel',Twist,queue_size=10)
rospy.init_node('bug2')
rate_dur = 10
rate = rospy.Rate(rate_dur)
rate_dur = 1/rate_dur
puntos = []
start = []
goal = []
temp = []

nfb = False
ilb = False
sl = 0
turnPID = ControlPID(rate_dur,kp = 0.4)
fowaPID = ControlPID(rate_dur,kp = 0.2,kd = 0.005)

# %% [markdown]
# Declaramos el callback de Odometría el cual se encarga de dar la posición del robot de acuerdo a sus cálculos de las velocidades hechas en cada motor.

# %%
def callbackOdom(msg):
    global pos
    global c_vel
    pos.linear.x = msg.pose.pose.position.x
    pos.linear.y = msg.pose.pose.position.y
    rot_q = msg.pose.pose.orientation
    (_,_,pos.angular.z) = euler_from_quaternion([rot_q.x, rot_q.y, rot_q.z, rot_q.w])
    #c_vel.linear.x = np.sqrt(msg.twist.twist.linear.x**2 + msg.twist.twist.linear.y**2)
    c_vel.linear.x = msg.twist.twist.linear.x
    c_vel.angular.z = msg.twist.twist.angular.z

# %% [markdown]
# Esta función sirve para dar la diferencia de ángulo entre dos ángulos en el plano cartesiano.

# %%
def smallest_angle_diff(t,s):
    a = t - s
    a -= 2*np.pi if a > np.pi else -2*np.pi if a < -np.pi else 0
    return a

# %% [markdown]
# Función para medir distancia entre dos puntos

# %%
def dis(src, goal):
    return np.sqrt((goal[0]-src[0])**2 + (goal[1]-src[1])**2)

# %% [markdown]
# Este callback verifica con el LiDAR los obstaculos más cercanos los cuales si se detecta alguno calcula la cantidad de freno y desviación para evitar colisión.

# %%
def callbackScan(msg):
    global nfb
    global ilb
    global sl

    #Get angles array
    scan = np.array(msg.ranges)
    ang = msg.angle_min - np.pi
    andf = msg.angle_max - np.pi
    inc = msg.angle_increment
    angles = np.arange(ang,andf+inc,inc)

    #Get only front detected points
    scan_f = scan[np.r_[-45:0]]
    scan_f = scan_f[~np.isnan(scan_f)]
    scan_f = scan_f[np.isfinite(scan_f)]

    #Get only left detected points
    anglesl = angles[np.r_[45:90]]
    scan_l = scan[np.r_[45:90]]
    anglesl = anglesl[~np.isnan(scan_l)]
    scan_l = scan_l[~np.isnan(scan_l)]
    anglesl = anglesl[np.isfinite(scan_l)]
    scan_l = scan_l[np.isfinite(scan_l)]

    #Get booleans if obstacle in front and wall in its left
    nfb = not scan_f[scan_f < 0.45].shape[0] > 0 and not scan_l[scan_l < 0.3].shape[0] > 0
    ilb = scan_l[scan_l < 0.45].shape[0] > 0

    #Calculate slope with regression and give it as error
    if scan_l[scan_l < 0.6].shape[0] >= 13:
        px = scan_l*np.cos(anglesl)
        py = scan_l*np.sin(anglesl)
        sl = np.sum((px - np.average(px))*(py -np.average(py)))/np.sum((px - np.average(px))**2)

# %% [markdown]
# Este callback recibe nuevos puntos objetivo

# %%
def callbackGoalPoint(msg):
    global puntos
    puntos.append([msg.pose.position.x, msg.pose.position.y])

# %% [markdown]
# Este es el primer estado el cual envía al robot la velocidad de giro necesaria para alcanzar el ángulo mínimo entre el turtlebot y el punto objetivo, y así iniciar haciendo un recorrido en línea recta.

# %%
class Turn(State):
    def __init__(self):
        State.__init__(self, outcomes=['turnr','fowardr','wait'])
        
    def execute(self, ud):
        global pos
        global c_vel
        global pub
        global rate
        global puntos
        global turnPID
        global goal
        global start

        if len(puntos) == 0:
            return 'wait'
        goal = puntos[0]
        vel = Twist()

        c_ang = np.arctan2(goal[1]-pos.linear.y,goal[0]-pos.linear.x)
        o_ang = smallest_angle_diff(c_ang,pos.angular.z)
        o_ang = o_ang if abs(o_ang) <= np.pi/4 else (np.pi/4)*np.sign(o_ang)
        turnPID.update(c_vel.angular.z, o_ang)
        vel.angular.z = turnPID.pred
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
        pub.publish(vel)
        rate.sleep()

        if abs(smallest_angle_diff(c_ang,pos.angular.z)) > 0.05:
            return 'turnr'
        else:
            start = [pos.linear.x,pos.linear.y]
            while c_vel.angular.z > 0.05:
                turnPID.update(c_vel.angular.z, 0)
                vel.angular.z = turnPID.pred
                vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
                pub.publish(vel)
                rate.sleep()
            vel.angular.z = 0
            pub.publish(vel)
            rate.sleep()
            return 'fowardr'

# %% [markdown]
# El segundo estado consiste en avanzar y corregir el rumbo si se está desviando a partir de un giro muy discreto. Si hay obstaculo aquí se aplica el freno y la desviación.

# %%
class Advance(State):
    def __init__(self):
        State.__init__(self, outcomes=['turnr','fowardr','wait','at'])
        
    def execute(self, ud):
        global pos
        global pub
        global rate
        global puntos

        global turnPID
        global fowaPID

        global nfb
        global temp

        goal = puntos[0]
        vel = Twist()

        c_ang = np.arctan2(goal[1]-pos.linear.y,goal[0]-pos.linear.x)
        o_ang = smallest_angle_diff(c_ang,pos.angular.z)
        o_ang = o_ang if abs(o_ang) <= np.pi/4 else (np.pi/4)*np.sign(o_ang)
        turnPID.update(c_vel.angular.z, o_ang)
        vel.angular.z = turnPID.pred
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)

        c_dis = dis([pos.linear.x,pos.linear.y],goal)
        o_dis = c_dis if abs(c_dis) <= 0.2 else 0.2*np.sign(c_dis)
        fowaPID.update(c_vel.linear.x, o_dis)
        vel.linear.x = fowaPID.pred
        vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
        pub.publish(vel)
        rate.sleep()
        
        if nfb:
            if c_dis > 0.05:
                return 'fowardr'
            else:
                puntos.pop(0)
                while c_vel.angular.z > 0.05 or c_vel.linear.x > 0.05:
                    turnPID.update(c_vel.angular.z, 0)
                    vel.angular.z = turnPID.pred
                    vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
                    fowaPID.update(c_vel.linear.x, 0)
                    vel.linear.x = fowaPID.pred
                    vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
                    pub.publish(vel)
                    rate.sleep()
                if len(puntos) == 0:
                    return 'wait'
                else:
                    return 'turnr'
        else:
            temp = [pos.linear.x,pos.linear.y]
            return 'at'

# %% [markdown]
# El tercer estado consiste de esperar nuevos puntos objetivo

# %%
class Wait(State):
    def __init__(self):
        State.__init__(self, outcomes=['turnr','wait'])
    def execute(self, ud):
        global pub
        global rate
        global start
        global pos
        vel = Twist()
        vel.angular.z = 0
        vel.linear.x = 0
        pub.publish(vel)
        rate.sleep()
        pub.publish(vel)
        rate.sleep()
        if (len(puntos)) > 0:
            start = [pos.linear.x,pos.linear.y]
            return 'turnr'
        else:
            return 'wait'

# %% [markdown]
# El estado de giro solo se activa cuando tiene obstaculo enfrente.

# %%
class Turn_so(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t','turnr'])
    def execute(self, ud):
        global pub
        global rate
        global rate_dur
        global nfb
        global ilb
        global c_vel
        global pos

        global start
        global goal
        global temp
        
        global turnPID
        global fowaPID
        
        vel = Twist()
        turnPID.update(c_vel.angular.z, -np.pi/4)
        vel.angular.z = turnPID.pred
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
        fowaPID.update(c_vel.linear.x, 0)
        vel.linear.x = fowaPID.pred
        vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
        pub.publish(vel)
        rate.sleep()

        ang = np.arctan2(start[1] - pos.linear.y, start[0] - pos.linear.x) - np.arctan2(goal[1] - pos.linear.y, goal[0] - pos.linear.x)
        if ang < 0.05 and dis(temp, [pos.linear.x,pos.linear.y]) > 0.5:
            temp = []
            while c_vel.angular.z > 0.05 or c_vel.linear.x > 0.05:
                    turnPID.update(c_vel.angular.z, 0)
                    vel.angular.z = turnPID.pred
                    vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
                    fowaPID.update(c_vel.linear.x, 0)
                    vel.linear.x = fowaPID.pred
                    vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
                    pub.publish(vel)
                    rate.sleep()
            return 'turnr'
            
        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# El estado de avance y giro se activa cuando no hay obstaculos enfrente ni a su izquierda.

# %%
class AdvanceTurn(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t','turnr'])
    def execute(self, ud):
        global pub
        global rate
        global nfb
        global ilb
        global c_vel
        global pos

        global start
        global goal
        global temp

        global turnPID
        global fowaPID
        
        vel = Twist()
        turnPID.update(c_vel.angular.z, np.pi/4)
        vel.angular.z = turnPID.pred
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
        fowaPID.update(c_vel.linear.x, 0.1)
        vel.linear.x = fowaPID.pred
        vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
        pub.publish(vel)
        rate.sleep()

        ang = np.arctan2(start[1] - pos.linear.y, start[0] - pos.linear.x) - np.arctan2(goal[1] - pos.linear.y, goal[0] - pos.linear.x)
        if ang < 0.05 and dis(temp, [pos.linear.x,pos.linear.y]) > 0.5:
            temp = []
            while c_vel.angular.z > 0.05 or c_vel.linear.x > 0.05:
                    turnPID.update(c_vel.angular.z, 0)
                    vel.angular.z = turnPID.pred
                    vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
                    fowaPID.update(c_vel.linear.x, 0)
                    vel.linear.x = fowaPID.pred
                    vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
                    pub.publish(vel)
                    rate.sleep()
            return 'turnr'
            
        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# El estado de avance se activa cuando no hay obstáculo en frente y tiene pared a su izquierda. Para estar paralelo a la pared utiliza la pendiente como error donde 0 sería que está totalmente paralelo.

# %%
class Advance_so(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t','turnr'])
    def execute(self, ud):
        global pub
        global rate
        global nfb
        global ilb
        global sl
        global pos

        global start
        global goal
        global temp

        global turnPID
        global fowaPID
        
        vel = Twist()
        turnPID.update(c_vel.angular.z, sl)
        vel.angular.z = turnPID.pred
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
        fowaPID.update(c_vel.linear.x, 0.2)
        vel.linear.x = fowaPID.pred
        vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
        pub.publish(vel)
        rate.sleep()

        ang = np.arctan2(start[1] - pos.linear.y, start[0] - pos.linear.x) - np.arctan2(goal[1] - pos.linear.y, goal[0] - pos.linear.x)
        if ang < 0.05 and dis(temp, [pos.linear.x,pos.linear.y]) > 0.5:
            temp = []
            while c_vel.angular.z > 0.05 or c_vel.linear.x > 0.05:
                    turnPID.update(c_vel.angular.z, 0)
                    vel.angular.z = turnPID.pred
                    vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
                    fowaPID.update(c_vel.linear.x, 0)
                    vel.linear.x = fowaPID.pred
                    vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
                    pub.publish(vel)
                    rate.sleep()
            return 'turnr'

        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# Ésta es la función principal donde se inicializan los nodos suscriptores y la máquina de estados.

# %%
def main():
    
    odom = rospy.Subscriber('/odom',Odometry,callbackOdom)
    scanS = rospy.Subscriber('/scan',LaserScan,callbackScan)
    Gpoints = rospy.Subscriber('/move_base_simple/goal',PoseStamped,callbackGoalPoint)
    
    sm = StateMachine(outcomes=['succeeded'])
    sm.userdata.sm_input = 0

    with sm:

        StateMachine.add('WAIT', Wait(), transitions={'turnr':'TURN','wait':'WAIT'})
        StateMachine.add('TURN', Turn(), transitions={'turnr':'TURN','fowardr':'FOWARD','wait':'WAIT'})
        StateMachine.add('FOWARD', Advance(), transitions={'turnr':'TURN','fowardr':'FOWARD','wait':'WAIT','at':'ADVANCETURN'})
        StateMachine.add('TURN_so', Turn_so(), transitions={'t':'TURN_so','at':'ADVANCETURN','a':'ADVANCE_so','turnr':'TURN'})
        StateMachine.add('ADVANCE_so', Advance_so(), transitions={'t':'TURN_so','at':'ADVANCETURN','a':'ADVANCE_so','turnr':'TURN'})
        StateMachine.add('ADVANCETURN', AdvanceTurn(), transitions={'t':'TURN_so','at':'ADVANCETURN','a':'ADVANCE_so','turnr':'TURN'})
    
    sis = smach_ros.IntrospectionServer('server_name', sm, '/SM_ROOT')
    rospy.sleep(1)
    sis.start()
    
    outcome = sm.execute()

    sis.stop()
    
    rospy.sleep(1)

# %% [markdown]
# Finalmente, para ejecutar el código oficialmente (sin antes haber ya ejecutado las celdas anteriores y lanzado el mundo de turtlebot en Gazebo), se ejecuta la siguiente celda para iniciar con el proceso:

# %%
if __name__ == '__main__':
    try:
        main()
    except rospy.ROSInterruptException:
        pass
    except KeyboardInterrupt:
        pass
# Out:
# [INFO] [1683590313.570253, 12.409000]: State machine starting in initial state 'WAIT' with userdata:
# 	['sm_input']
# [INFO] [1683590313.671984, 12.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590313.871454, 12.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590314.071783, 12.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590314.272585, 13.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590314.472671, 13.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590314.673281, 13.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590314.873645, 13.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590315.074366, 13.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590315.274669, 14.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590315.476943, 14.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590315.675445, 14.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590315.875507, 14.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590316.076732, 14.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590316.277444, 15.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590316.477381, 15.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590316.678503, 15.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590316.878367, 15.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590317.079809, 15.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590317.278947, 16.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590317.479776, 16.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590317.679998, 16.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590317.880293, 16.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590318.080877, 16.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590318.281642, 17.110000]: State machine transitioning 'WAIT':'turnr'-->'TURN'
# [INFO] [1683590318.481741, 17.310000]: State machine transitioning 'TURN':'fowardr'-->'FOWARD'
# [INFO] [1683590318.582036, 17.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590318.683143, 17.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590318.785565, 17.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590318.884530, 17.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590318.983616, 17.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.083297, 17.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.186338, 18.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.285034, 18.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.384470, 18.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.484243, 18.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.585802, 18.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.685318, 18.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.785311, 18.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.885277, 18.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590319.985660, 18.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.087491, 18.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.186417, 19.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.286263, 19.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.389739, 19.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.488117, 19.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.587033, 19.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.687611, 19.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.788548, 19.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.887450, 19.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590320.988277, 19.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.088153, 19.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.188521, 20.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.288608, 20.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.388738, 20.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.488823, 20.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.589171, 20.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.690873, 20.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.790276, 20.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.890215, 20.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590321.990067, 20.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.090064, 20.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.191353, 21.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.291027, 21.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.392822, 21.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.494945, 21.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.592806, 21.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.692669, 21.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.792498, 21.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.893507, 21.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590322.992693, 21.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.092658, 21.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.192954, 22.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.292778, 22.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.393205, 22.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.493989, 22.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.594114, 22.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.695263, 22.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.797208, 22.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.895499, 22.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590323.995272, 22.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590324.095822, 22.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590324.195638, 23.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590324.296685, 23.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590324.395940, 23.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590324.496063, 23.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590324.598116, 23.410000]: State machine transitioning 'FOWARD':'at'-->'ADVANCETURN'
# [INFO] [1683590324.697244, 23.510000]: State machine transitioning 'ADVANCETURN':'t'-->'TURN_so'
# [INFO] [1683590324.796676, 23.610000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590324.897650, 23.710000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590324.997522, 23.810000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.097170, 23.910000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.197333, 24.010000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.298204, 24.110000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.397872, 24.210000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.498971, 24.310000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.600522, 24.410000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.699481, 24.510000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.799073, 24.610000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.899155, 24.710000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590325.999125, 24.810000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590326.100294, 24.910000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590326.200037, 25.010000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590326.300165, 25.110000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590326.402303, 25.210000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590326.501465, 25.310000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590326.601435, 25.410000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590326.701526, 25.510000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590326.804509, 25.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590326.902913, 25.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590327.002455, 25.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590327.102200, 25.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590327.202255, 26.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590327.302317, 26.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590327.402670, 26.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590327.502917, 26.310000]: State machine transitioning 'ADVANCE_so':'t'-->'TURN_so'
# [INFO] [1683590327.603672, 26.410000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590327.704195, 26.510000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590327.804300, 26.610000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590327.904420, 26.710000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.009180, 26.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.106733, 26.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.207095, 27.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.305942, 27.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.405624, 27.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.506021, 27.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.605643, 27.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.706034, 27.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.806320, 27.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590328.906232, 27.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590329.006360, 27.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590329.106362, 27.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590329.207111, 28.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590329.307038, 28.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590329.409755, 28.210000]: State machine transitioning 'ADVANCE_so':'at'-->'ADVANCETURN'
# [INFO] [1683590329.508604, 28.310000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590329.608410, 28.410000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590329.708159, 28.510000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590329.808185, 28.610000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590329.908585, 28.710000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590330.009822, 28.810000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590330.109183, 28.910000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590330.209927, 29.010000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590330.309663, 29.110000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590330.409749, 29.210000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590330.510063, 29.310000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590330.610394, 29.410000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590330.710342, 29.510000]: State machine transitioning 'ADVANCETURN':'a'-->'ADVANCE_so'
# [INFO] [1683590330.812467, 29.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590330.911341, 29.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.012064, 29.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.111562, 29.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.211482, 30.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.311813, 30.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.412356, 30.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.512413, 30.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.612478, 30.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.714159, 30.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.814074, 30.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590331.914003, 30.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.015354, 30.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.114506, 30.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.214057, 31.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.314044, 31.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.414162, 31.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.514885, 31.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.614810, 31.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.714967, 31.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.815386, 31.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590332.915735, 31.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590333.016191, 31.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590333.116032, 31.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590333.216836, 32.010000]: State machine transitioning 'ADVANCE_so':'t'-->'TURN_so'
# [INFO] [1683590333.317151, 32.110000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590333.416666, 32.210000]: State machine transitioning 'ADVANCE_so':'t'-->'TURN_so'
# [INFO] [1683590333.516677, 32.310000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590333.617502, 32.410000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590333.717319, 32.510000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590333.817870, 32.610000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590333.921529, 32.713000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.020299, 32.810000]: State machine transitioning 'ADVANCE_so':'t'-->'TURN_so'
# [INFO] [1683590334.118679, 32.910000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.218466, 33.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.318681, 33.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.419830, 33.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.519933, 33.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.619557, 33.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.719597, 33.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.820751, 33.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590334.920160, 33.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.020473, 33.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.120812, 33.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.221503, 34.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.321232, 34.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.421128, 34.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.521805, 34.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.621709, 34.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.721849, 34.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.822402, 34.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590335.925258, 34.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.023774, 34.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.123156, 34.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.223333, 35.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.323432, 35.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.425757, 35.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.524493, 35.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.627827, 35.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.726791, 35.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.825622, 35.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590336.924997, 35.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.026789, 35.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.126328, 35.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.225528, 36.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.325338, 36.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.425943, 36.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.526688, 36.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.626908, 36.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.726552, 36.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.826827, 36.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590337.928783, 36.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.029118, 36.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.129327, 36.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.229217, 37.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.328124, 37.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.428652, 37.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.529790, 37.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.629740, 37.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.729454, 37.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.829700, 37.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590338.929577, 37.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.030627, 37.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.135366, 37.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.232301, 38.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.331251, 38.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.431383, 38.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.531055, 38.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.630974, 38.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.731238, 38.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.831672, 38.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590339.932007, 38.710000]: State machine transitioning 'ADVANCE_so':'at'-->'ADVANCETURN'
# [INFO] [1683590340.031829, 38.810000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.132943, 38.910000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.232500, 39.010000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.332703, 39.110000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.432804, 39.210000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.534064, 39.310000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.633720, 39.410000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.733722, 39.510000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.834035, 39.610000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590340.939026, 39.712000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590341.034690, 39.810000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590341.134353, 39.910000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590341.234838, 40.010000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590341.335834, 40.110000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590341.435556, 40.210000]: State machine transitioning 'ADVANCETURN':'at'-->'ADVANCETURN'
# [INFO] [1683590341.535347, 40.310000]: State machine transitioning 'ADVANCETURN':'a'-->'ADVANCE_so'
# [INFO] [1683590341.636357, 40.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590341.736230, 40.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590341.836100, 40.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590341.936255, 40.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.036433, 40.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.136819, 40.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.236906, 41.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.337409, 41.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.437606, 41.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.539603, 41.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.638947, 41.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.739480, 41.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.838779, 41.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590342.938781, 41.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.039072, 41.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.139191, 41.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.241439, 42.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.340771, 42.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.440029, 42.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.540665, 42.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.640193, 42.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.740267, 42.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.841632, 42.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590343.941251, 42.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.040962, 42.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.141263, 42.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.243101, 43.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.342637, 43.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.442209, 43.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.542103, 43.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.642587, 43.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.742548, 43.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.843014, 43.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590344.942919, 43.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.043120, 43.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.143723, 43.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.243719, 44.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.343935, 44.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.444844, 44.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.544380, 44.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.644417, 44.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.749304, 44.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590345.846364, 44.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590346.647084, 45.410000]: State machine transitioning 'ADVANCE_so':'turnr'-->'TURN'
# [INFO] [1683590346.747638, 45.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590346.847352, 45.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590346.947877, 45.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.048187, 45.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.149318, 45.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.248675, 46.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.349128, 46.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.449564, 46.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.549228, 46.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.649919, 46.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.751278, 46.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.850947, 46.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590347.952395, 46.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.051972, 46.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.151232, 46.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.250800, 47.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.352982, 47.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.452275, 47.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.551818, 47.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.651458, 47.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.752195, 47.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.852449, 47.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590348.953885, 47.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.053799, 47.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.153538, 47.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.253436, 48.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.353886, 48.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.453520, 48.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.554126, 48.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.654838, 48.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.755797, 48.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590349.855007, 48.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590350.055972, 48.810000]: State machine transitioning 'TURN':'fowardr'-->'FOWARD'
# [INFO] [1683590350.155857, 48.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590350.255719, 49.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590350.356275, 49.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590350.456245, 49.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590350.557296, 49.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590350.657307, 49.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590350.757776, 49.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590350.857378, 49.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590350.957399, 49.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.057941, 49.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.158391, 49.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.258507, 50.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.358022, 50.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.459964, 50.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.560398, 50.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.660651, 50.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.760938, 50.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.861861, 50.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590351.961487, 50.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.061275, 50.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.162062, 50.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.262120, 51.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.361873, 51.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.462182, 51.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.563332, 51.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.662724, 51.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.763176, 51.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.864345, 51.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590352.963794, 51.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.063805, 51.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.164472, 51.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.264263, 52.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.364596, 52.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.464675, 52.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.564744, 52.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.665972, 52.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.766159, 52.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.865691, 52.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590353.965847, 52.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.066146, 52.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.167600, 52.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.266981, 53.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.366832, 53.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.467092, 53.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.569351, 53.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.668385, 53.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.771012, 53.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.869751, 53.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590354.969111, 53.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590355.069175, 53.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590355.170830, 53.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590355.269516, 54.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590355.369292, 54.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590355.469517, 54.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590355.570591, 54.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590355.670752, 54.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590355.770868, 54.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590356.171096, 54.910000]: State machine transitioning 'FOWARD':'wait'-->'WAIT'
# [INFO] [1683590356.371964, 55.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590356.572680, 55.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590356.774307, 55.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590356.973037, 55.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590357.173819, 55.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590357.373969, 56.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590357.574508, 56.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590357.775114, 56.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590357.975911, 56.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590358.175635, 56.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590358.376698, 57.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590358.576651, 57.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590358.777936, 57.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590358.979344, 57.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590359.177958, 57.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590359.379143, 58.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590359.579881, 58.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590359.780531, 58.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590359.982798, 58.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590360.182085, 58.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590360.381756, 59.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590360.582294, 59.310000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590360.782658, 59.510000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590360.982842, 59.710000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590361.183215, 59.910000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590361.383764, 60.110000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590361.583886, 60.310000]: State machine transitioning 'WAIT':'turnr'-->'TURN'
# [INFO] [1683590361.686926, 60.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590361.785018, 60.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590361.885115, 60.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590361.984781, 60.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.084934, 60.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.185869, 60.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.285685, 61.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.385857, 61.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.486026, 61.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.586415, 61.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.687820, 61.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.788478, 61.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.887563, 61.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590362.987321, 61.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.087664, 61.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.190116, 61.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.288910, 62.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.390600, 62.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.491860, 62.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.590000, 62.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.689793, 62.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.789728, 62.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.890128, 62.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590363.989913, 62.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.090325, 62.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.190387, 62.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.290699, 63.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.390636, 63.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.491210, 63.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.591070, 63.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.691802, 63.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.792174, 63.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.891976, 63.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590364.993106, 63.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.092990, 63.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.192465, 63.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.293007, 64.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.393042, 64.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.493595, 64.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.594842, 64.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.694241, 64.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.794803, 64.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.894476, 64.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590365.994598, 64.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.094969, 64.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.195866, 64.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.297146, 65.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.396074, 65.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.495745, 65.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.596092, 65.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.696290, 65.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.796210, 65.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.896311, 65.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590366.997233, 65.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590367.096995, 65.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590369.103539, 67.810000]: State machine transitioning 'TURN':'fowardr'-->'FOWARD'
# [INFO] [1683590369.204558, 67.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590369.303097, 68.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590369.403592, 68.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590369.503083, 68.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590369.603036, 68.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590369.704357, 68.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590369.804118, 68.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590369.904040, 68.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.004269, 68.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.104664, 68.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.204703, 68.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.305565, 69.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.406093, 69.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.505700, 69.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.605389, 69.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.706087, 69.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.806442, 69.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590370.907511, 69.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590371.006729, 69.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590371.107442, 69.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590371.207327, 69.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590371.307073, 70.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590371.407058, 70.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590371.507942, 70.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590371.608636, 70.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590371.707982, 70.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# ...
# [INFO] [1683590394.563128, 93.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590394.663356, 93.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590394.763151, 93.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590394.862959, 93.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590394.963635, 93.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590395.063441, 93.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590395.164017, 93.810000]: State machine transitioning 'ADVANCE_so':'t'-->'TURN_so'
# [INFO] [1683590395.264625, 93.910000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590395.364544, 94.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590395.464619, 94.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590395.564476, 94.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590395.664572, 94.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590395.765305, 94.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590395.865196, 94.510000]: State machine transitioning 'ADVANCE_so':'t'-->'TURN_so'
# [INFO] [1683590395.965341, 94.610000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# [INFO] [1683590396.065866, 94.710000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590396.166128, 94.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590396.266029, 94.910000]: State machine transitioning 'ADVANCE_so':'t'-->'TURN_so'
# [INFO] [1683590396.368124, 95.010000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590396.469131, 95.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590396.567846, 95.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590396.669204, 95.310000]: State machine transitioning 'ADVANCE_so':'t'-->'TURN_so'
# [INFO] [1683590396.768504, 95.410000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# [INFO] [1683590396.868787, 95.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590396.969394, 95.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.068653, 95.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.169632, 95.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.269651, 95.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.369234, 96.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.469404, 96.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.571153, 96.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.670391, 96.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.770072, 96.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.869969, 96.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590397.970348, 96.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.070844, 96.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.170757, 96.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.271051, 96.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.373312, 97.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.472113, 97.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.572119, 97.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.674276, 97.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.775640, 97.410000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.875700, 97.510000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590398.976031, 97.610000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590399.076226, 97.710000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590399.176265, 97.810000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590399.276596, 97.910000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590399.376679, 98.010000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590399.476846, 98.110000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590399.577421, 98.210000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590399.678242, 98.310000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# [INFO] [1683590400.379135, 99.010000]: State machine transitioning 'ADVANCE_so':'turnr'-->'TURN'
# [INFO] [1683590400.479188, 99.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590400.580449, 99.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590400.680090, 99.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590400.779854, 99.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590400.881292, 99.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590400.980528, 99.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.081123, 99.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.182731, 99.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.282439, 99.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.381662, 100.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.482011, 100.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.582735, 100.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.682773, 100.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.782923, 100.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.884217, 100.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590401.984031, 100.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.084609, 100.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.183320, 100.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.283664, 100.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.383977, 101.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.485246, 101.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.584293, 101.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.684656, 101.310000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.784692, 101.410000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.886477, 101.510000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590402.985904, 101.610000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590403.087296, 101.710000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590403.187464, 101.810000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590403.286394, 101.910000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590403.386350, 102.010000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590403.486292, 102.110000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590403.586692, 102.210000]: State machine transitioning 'TURN':'turnr'-->'TURN'
# [INFO] [1683590403.788142, 102.410000]: State machine transitioning 'TURN':'fowardr'-->'FOWARD'
# [INFO] [1683590403.888134, 102.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590403.988812, 102.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.088935, 102.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.188737, 102.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.288983, 102.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.389243, 103.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.489075, 103.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.588986, 103.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.689404, 103.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.789535, 103.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.889623, 103.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590404.990137, 103.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.091639, 103.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.191202, 103.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.290840, 103.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.391833, 104.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.492391, 104.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.591696, 104.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.692334, 104.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.792217, 104.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.892963, 104.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590405.993464, 104.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.093560, 104.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.193397, 104.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.293258, 104.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.394883, 105.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.494838, 105.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.594442, 105.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.694064, 105.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.795259, 105.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.895130, 105.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590406.995154, 105.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.095161, 105.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.195632, 105.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.295677, 105.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.397133, 106.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.496313, 106.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.597784, 106.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.697085, 106.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.797247, 106.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.897038, 106.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590407.997092, 106.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.097579, 106.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.197594, 106.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.297816, 106.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.398025, 107.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.498475, 107.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.598688, 107.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.698885, 107.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.799006, 107.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590408.900868, 107.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.000256, 107.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.100244, 107.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.200843, 107.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.301807, 107.910000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.401245, 108.010000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.501414, 108.110000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.601672, 108.210000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.701610, 108.310000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.801809, 108.410000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590409.903796, 108.510000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590410.003517, 108.610000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590410.102992, 108.710000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590410.203536, 108.810000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683590411.004600, 109.610000]: State machine transitioning 'FOWARD':'wait'-->'WAIT'
# [INFO] [1683590411.205131, 109.810000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590411.405831, 110.010000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590411.606078, 110.210000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590411.806926, 110.410000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590412.006920, 110.610000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590412.207060, 110.810000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590412.408800, 111.010000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590412.608913, 111.210000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590412.809463, 111.410000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590413.009283, 111.610000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590413.209456, 111.810000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590413.410497, 112.010000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590413.611327, 112.210000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590413.811436, 112.410000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683590414.011592, 112.610000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
