# %% [markdown]
# # Bug1
# ## Equipo 3

# %% [markdown]
# Primero se importan las librerias necesarias.

# %%
import rospy
import numpy as np
from geometry_msgs.msg import Twist, PoseStamped
from nav_msgs.msg import Odometry
from sensor_msgs.msg import LaserScan
from smach import State, StateMachine
import smach_ros
from tf.transformations import euler_from_quaternion

# %% [markdown]
# Controlador simple

# %%
class ControlPID:
    def __init__(self, rate, kp = 1, ki = 0, kd = 0):
        self.rate = rate
        self.kp = kp
        self.ki = ki
        self.kd = kd
        self.i = 0
        self.ea = 0
        self.pred = 0

    def update(self, current, goal):
        ep = goal - current
        self.i = self.i + self.ki*ep*self.rate
        ed = (ep - self.ea)/self.rate
        self.ea = ep
        self.pred = current + ep*self.kp + self.i + ed*self.kd

# %% [markdown]
# Luego se declaran variables globales.

# %%
pos = Twist()
c_vel = Twist()
pub = rospy.Publisher('/cmd_vel',Twist,queue_size=10)
rospy.init_node('bug1')
rate_dur = 10
rate = rospy.Rate(rate_dur)
rate_dur = 1/rate_dur
puntos = []
goal = []

nfb = False
ilb = False
sl = 0
sor = 1
temp_start = []
temp_goal = []
dis_r = 0
dis_l = 0
wsd = False
turnPID = ControlPID(rate_dur,kp = 4)
fowaPID = ControlPID(rate_dur,kp = 1)

# %% [markdown]
# Declaramos el callback de Odometría el cual se encarga de dar la posición del robot de acuerdo a sus cálculos de las velocidades hechas en cada motor.

# %%
def callbackOdom(msg):
    global pos
    global c_vel
    pos.linear.x = msg.pose.pose.position.x
    pos.linear.y = msg.pose.pose.position.y
    rot_q = msg.pose.pose.orientation
    (_,_,pos.angular.z) = euler_from_quaternion([rot_q.x, rot_q.y, rot_q.z, rot_q.w])
    c_vel.linear.x = np.sqrt(msg.twist.twist.linear.x**2 + msg.twist.twist.linear.y**2)
    c_vel.angular.z = msg.twist.twist.angular.z

# %% [markdown]
# Esta función sirve para dar la diferencia de ángulo entre dos ángulos en el plano cartesiano.

# %%
def smallest_angle_diff(t,s):
    a = t - s
    a -= 2*np.pi if a > np.pi else -2*np.pi if a < -np.pi else 0
    return a

# %% [markdown]
# Función para medir distancia entre dos puntos

# %%
def dis(src, goal):
    return np.sqrt((goal[0]-src[0])**2 + (goal[1]-src[1])**2)

# %% [markdown]
# Este callback verifica con el LiDAR los obstaculos más cercanos los cuales si se detecta alguno calcula la cantidad de freno y desviación para evitar colisión.

# %%
def callbackScan(msg):
    global nfb
    global ilb
    global sl

    #Get angles array
    scan = np.array(msg.ranges)
    ang = msg.angle_min - np.pi
    andf = msg.angle_max - np.pi
    inc = msg.angle_increment
    angles = np.arange(ang,andf+inc,inc)
    
    #Get only front detected points
    scan_f = scan[np.r_[-45:0]]
    scan_f = scan_f[~np.isnan(scan_f)]
    scan_f = scan_f[np.isfinite(scan_f)]

    #Get only left detected points
    anglesl = angles[np.r_[45:90]]
    scan_l = scan[np.r_[45:90]]
    anglesl = anglesl[~np.isnan(scan_l)]
    scan_l = scan_l[~np.isnan(scan_l)]
    anglesl = anglesl[np.isfinite(scan_l)]
    scan_l = scan_l[np.isfinite(scan_l)]

    #Get booleans if obstacle in front and wall in its left
    nfb = not scan_f[scan_f < 0.45].shape[0] > 0 and not scan_l[scan_l < 0.3].shape[0] > 0
    ilb = scan_l[scan_l < 0.45].shape[0] > 0

    #Calculate slope with regression and give it as error
    if scan_l[scan_l < 0.6].shape[0] >= 13:
        px = scan_l*np.cos(anglesl)
        py = scan_l*np.sin(anglesl)
        sl = np.sum((px - np.average(px))*(py -np.average(py)))/np.sum((px - np.average(px))**2)

# %% [markdown]
# Este callback recibe nuevos puntos objetivo

# %%
def callbackGoalPoint(msg):
    global puntos
    puntos.append([msg.pose.position.x, msg.pose.position.y])

# %% [markdown]
# Este es el primer estado el cual envía al robot la velocidad de giro necesaria para alcanzar el ángulo mínimo entre el turtlebot y el punto objetivo, y así iniciar haciendo un recorrido en línea recta.

# %%
class Turn(State):
    def __init__(self):
        State.__init__(self, outcomes=['turnr','fowardr','wait'])
        
    def execute(self, ud):
        global pos
        global c_vel
        global pub
        global rate
        global puntos
        global turnPID
        global goal

        if len(puntos) == 0:
            return 'wait'
        goal = puntos[0]
        vel = Twist()

        c_ang = np.arctan2(goal[1]-pos.linear.y,goal[0]-pos.linear.x)
        o_ang = smallest_angle_diff(c_ang,pos.angular.z)
        o_ang = o_ang if abs(o_ang) <= np.pi/4 else (np.pi/4)*np.sign(o_ang)
        turnPID.update(c_vel.angular.z, o_ang)
        vel.angular.z = turnPID.pred
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
        pub.publish(vel)
        rate.sleep()

        if abs(smallest_angle_diff(c_ang,pos.angular.z)) > 0.05:
            return 'turnr'
        else:
            vel.angular.z = 0
            pub.publish(vel)
            rate.sleep()
            pub.publish(vel)
            rate.sleep()
            return 'fowardr'

# %% [markdown]
# El segundo estado consiste en avanzar y corregir el rumbo si se está desviando a partir de un giro muy discreto. Si hay obstaculo aquí se aplica el freno y la desviación.

# %%
class Advance(State):
    def __init__(self):
        State.__init__(self, outcomes=['turnr','fowardr','wait','at'])
        
    def execute(self, ud):
        global pos
        global pub
        global rate
        global puntos

        global turnPID
        global fowaPID

        global nfb
        global temp_start
        global temp_goal

        goal = puntos[0]
        vel = Twist()

        c_ang = np.arctan2(goal[1]-pos.linear.y,goal[0]-pos.linear.x)
        o_ang = smallest_angle_diff(c_ang,pos.angular.z)
        o_ang = o_ang if abs(o_ang) <= np.pi/4 else (np.pi/4)*np.sign(o_ang)
        turnPID.update(c_vel.angular.z, o_ang)
        vel.angular.z = turnPID.pred
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)

        c_dis = dis([pos.linear.x,pos.linear.y],goal)
        o_dis = c_dis if abs(c_dis) <= 0.2 else 0.2*np.sign(c_dis)
        fowaPID.update(c_vel.linear.x, o_dis)
        vel.linear.x = fowaPID.pred
        vel.linear.x = vel.linear.x if abs(vel.linear.x) <= 0.2 else 0.2*np.sign(vel.linear.x)
        pub.publish(vel)
        rate.sleep()
        
        if nfb:
            if c_dis > 0.05:
                return 'fowardr'
            else:
                puntos.pop(0)
                if len(puntos) == 0:
                    return 'wait'
                else:
                    return 'turnr'
        else:
            temp_start = [pos.linear.x,pos.linear.y]
            temp_goal = [pos.linear.x,pos.linear.y]
            return 'at'

# %% [markdown]
# El tercer estado consiste de esperar nuevos puntos objetivo

# %%
class Wait(State):
    def __init__(self):
        State.__init__(self, outcomes=['turnr','wait'])
    def execute(self, ud):
        global pub
        global rate
        vel = Twist()
        vel.angular.z = 0
        vel.linear.x = 0
        pub.publish(vel)
        rate.sleep()
        pub.publish(vel)
        rate.sleep()
        if (len(puntos)) > 0:
            return 'turnr'
        else:
            return 'wait'

# %% [markdown]
# El estado de giro solo se activa cuando tiene obstaculo enfrente.

# %%
class Turn_so(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t','turnr'])
    def execute(self, ud):
        global pub
        global rate
        global rate_dur
        global nfb
        global ilb
        global c_vel

        global wsd
        global temp_goal
        global goal
        global dis_l
        global dis_r
        global sor
        
        vel = Twist()
        turnPID.update(c_vel.angular.z, -np.pi/4*sor)
        vel.angular.z = turnPID.pred
        pub.publish(vel)
        rate.sleep()

        if not wsd:
            t_temp_goal = [pos.linear.x,pos.linear.y]
            temp_goal = t_temp_goal if dis(t_temp_goal,goal) < dis(temp_goal,goal) else temp_goal
            dis_r += c_vel.linear.x*rate_dur + dis_l if t_temp_goal == temp_goal else 0
            dis_l = 0 if t_temp_goal == temp_goal else dis_l
            dis_l += c_vel.linear.x*rate_dur if t_temp_goal != temp_goal else 0
            print(dis_l, dis_r,c_vel.linear.x*rate_dur)
            if dis(t_temp_goal,temp_start) < 0.2 and (dis_l + dis_r) > 1:
                wsd = True
        else:
            if dis_l > dis_r:
                sor = -1
            else:
                sor = 1
            if dis([pos.linear.x,pos.linear.y],temp_goal) < 0.1:
                temp_goal = []
                dis_l = 0
                dis_r = 0
                wsd = False
                return 'turnr'
            
        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# El estado de avance y giro se activa cuando no hay obstaculos enfrente ni a su izquierda.

# %%
class AdvanceTurn(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t','turnr'])
    def execute(self, ud):
        global pub
        global rate
        global nfb
        global ilb
        global c_vel

        global wsd
        global temp_goal
        global goal
        global dis_l
        global dis_r
        global sor
        
        vel = Twist()
        turnPID.update(c_vel.angular.z, np.pi/4)
        vel.angular.z = turnPID.pred
        fowaPID.update(c_vel.linear.x, 0.1)
        vel.linear.x = fowaPID.pred
        print(vel.angular.z)
        pub.publish(vel)
        rate.sleep()

        if not wsd:
            t_temp_goal = [pos.linear.x,pos.linear.y]
            temp_goal = t_temp_goal if dis(t_temp_goal,goal) < dis(temp_goal,goal) else temp_goal
            dis_r += c_vel.linear.x*rate_dur + dis_l if t_temp_goal == temp_goal else 0
            dis_l = 0 if t_temp_goal == temp_goal else dis_l
            dis_l += c_vel.linear.x*rate_dur if t_temp_goal != temp_goal else 0
            print(dis_l, dis_r,c_vel.linear.x*rate_dur)
            if dis(t_temp_goal,temp_start) < 0.2 and (dis_l + dis_r) > 1:
                wsd = True
        else:
            if dis_l > dis_r:
                sor = -1
            else:
                sor = 1
            if dis([pos.linear.x,pos.linear.y],temp_goal) < 0.1:
                temp_goal = []
                dis_l = 0
                dis_r = 0
                wsd = False
                return 'turnr'
            
        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# El estado de avance se activa cuando no hay obstáculo en frente y tiene pared a su izquierda. Para estar paralelo a la pared utiliza la pendiente como error donde 0 sería que está totalmente paralelo.

# %%
class Advance_so(State):
    def __init__(self):
        State.__init__(self, outcomes=['a','at','t','turnr'])
    def execute(self, ud):
        global pub
        global rate
        global nfb
        global ilb
        global sl

        global wsd
        global temp_goal
        global goal
        global dis_l
        global dis_r
        global sor
        
        vel = Twist()
        turnPID.update(c_vel.angular.z, sl)
        vel.angular.z = turnPID.pred
        vel.angular.z = vel.angular.z if abs(vel.angular.z) <= np.pi/4 else (np.pi/4)*np.sign(vel.angular.z)
        fowaPID.update(c_vel.linear.x, 0.2)
        vel.linear.x = fowaPID.pred
        pub.publish(vel)
        rate.sleep()

        if not wsd:
            t_temp_goal = [pos.linear.x,pos.linear.y]
            temp_goal = t_temp_goal if dis(t_temp_goal,goal) < dis(temp_goal,goal) else temp_goal
            dis_r += c_vel.linear.x*rate_dur + dis_l if t_temp_goal == temp_goal else 0
            dis_l = 0 if t_temp_goal == temp_goal else dis_l
            dis_l += c_vel.linear.x*rate_dur if t_temp_goal != temp_goal else 0
            print(dis_l, dis_r,c_vel.linear.x*rate_dur)
            if dis(t_temp_goal,temp_start) < 0.2 and (dis_l + dis_r) > 1:
                wsd = True
        else:
            if dis_l > dis_r:
                sor = -1
            else:
                sor = 1
            if dis([pos.linear.x,pos.linear.y],temp_goal) < 0.1:
                temp_goal = []
                dis_l = 0
                dis_r = 0
                wsd = False
                return 'turnr'

        if not nfb:
            return "t"
        elif ilb:
            return "a"
        else:
            return "at"

# %% [markdown]
# Ésta es la función principal donde se inicializan los nodos suscriptores y la máquina de estados.

# %%
def main():
    
    odom = rospy.Subscriber('/odom_gazebo',Odometry,callbackOdom)
    scanS = rospy.Subscriber('/scan',LaserScan,callbackScan)
    Gpoints = rospy.Subscriber('/move_base_simple/goal',PoseStamped,callbackGoalPoint)
    
    sm = StateMachine(outcomes=['succeeded'])
    sm.userdata.sm_input = 0

    with sm:

        StateMachine.add('WAIT', Wait(), transitions={'turnr':'TURN','wait':'WAIT'})
        StateMachine.add('TURN', Turn(), transitions={'turnr':'TURN','fowardr':'FOWARD','wait':'WAIT'})
        StateMachine.add('FOWARD', Advance(), transitions={'turnr':'TURN','fowardr':'FOWARD','wait':'WAIT','at':'ADVANCETURN'})
        StateMachine.add('TURN_so', Turn_so(), transitions={'t':'TURN_so','at':'ADVANCETURN','a':'ADVANCE_so','turnr':'TURN'})
        StateMachine.add('ADVANCE_so', Advance_so(), transitions={'t':'TURN_so','at':'ADVANCETURN','a':'ADVANCE_so','turnr':'TURN'})
        StateMachine.add('ADVANCETURN', AdvanceTurn(), transitions={'t':'TURN_so','at':'ADVANCETURN','a':'ADVANCE_so','turnr':'TURN'})
    
    sis = smach_ros.IntrospectionServer('server_name', sm, '/SM_ROOT')
    rospy.sleep(1)
    sis.start()
    
    outcome = sm.execute()

]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400840.198696, 89.674000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400840.299393, 89.774000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400840.399466, 89.874000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400840.499769, 89.974000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400840.600144, 90.074000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400840.700249, 90.174000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400840.800198, 90.274000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400840.900453, 90.374000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.001173, 90.474000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.101030, 90.574000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.201237, 90.674000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.301112, 90.774000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.402161, 90.874000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.502776, 90.974000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.602912, 91.074000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.703340, 91.174000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.803282, 91.274000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400841.903214, 91.374000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.003585, 91.474000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.103404, 91.574000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.204007, 91.674000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.304294, 91.774000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.404488, 91.874000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.504799, 91.974000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.605490, 92.074000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.704999, 92.174000]: State machine transitioning 'FOWARD':'fowardr'-->'FOWARD'
# [INFO] [1683400842.805019, 92.274000]: State machine transitioning 'FOWARD':'at'-->'ADVANCETURN'
# 3.156315235907786
# 0 0.01995731065893947 0.01995731065893947
# [INFO] [1683400842.905179, 92.374000]: State machine transitioning 'ADVANCETURN':'t'-->'TURN_so'
# 0 0.03993430569530982 0.01997699503637035
# [INFO] [1683400843.005718, 92.474000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.05991381627348358 0.01997951057817376
# [INFO] [1683400843.106078, 92.574000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.07965900788306934 0.019745191609585766
# [INFO] [1683400843.206377, 92.674000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.09774412639405297 0.018085118510983635
# [INFO] [1683400843.306820, 92.774000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.11150123203587045 0.013757105641817483
# [INFO] [1683400843.406956, 92.874000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.11818153531748155 0.006680303281611089
# [INFO] [1683400843.506985, 92.974000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.12313674455583427 0.004955209238352725
# [INFO] [1683400843.607865, 93.074000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.12801496218058944 0.004878217624755173
# [INFO] [1683400843.707866, 93.174000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.132085141953093 0.004070179772503576
# [INFO] [1683400843.807873, 93.274000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.13556479866921325 0.0034796567161202324
# [INFO] [1683400843.908396, 93.374000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.13904558095725617 0.003480782288042906
# [INFO] [1683400844.008348, 93.474000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.1429911875619061 0.00394560660464994
# [INFO] [1683400844.109000, 93.574000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.14727183341159555 0.004280645849689466
# [INFO] [1683400844.208832, 93.674000]: State machine transitioning 'TURN_so':'t'-->'TURN_so'
# 0 0.1514367560738169 0.004164922662221341
# [INFO] [1683400844.308804, 93.774000]: State machine transitioning 'TURN_so':'a'-->'ADVANCE_so'
# 0 0.15529383676311156 0.0038570806892946545
# [INFO] [1683400844.409168, 93.874000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# 0 0.16573740664525022 0.010443569882138667
# [INFO] [1683400844.509883, 93.974000]: State machine transitioning 'ADVANCE_so':'a'-->'ADVANCE_so'
# 0
]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400930.862210, 180.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400931.062185, 180.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400931.262152, 180.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400931.463087, 180.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400931.663428, 180.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400931.863904, 181.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400932.063966, 181.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400932.264555, 181.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400932.464837, 181.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400932.665023, 181.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400932.865668, 182.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400933.067467, 182.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400933.267082, 182.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400933.467528, 182.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400933.667661, 182.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400933.868557, 183.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400934.069475, 183.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400934.270302, 183.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400934.470502, 183.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400934.670719, 183.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400934.871316, 184.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400935.072017, 184.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400935.272511, 184.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400935.472671, 184.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400935.672880, 184.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400935.873429, 185.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400936.073977, 185.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400936.274558, 185.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400936.475204, 185.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400936.676270, 185.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400936.876727, 186.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400937.076594, 186.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400937.277213, 186.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400937.477616, 186.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400937.678456, 186.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400937.878071, 187.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400938.078779, 187.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400938.278876, 187.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400938.479353, 187.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400938.679299, 187.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400938.880022, 188.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400939.080714, 188.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400939.281110, 188.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400939.481445, 188.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400939.682000, 188.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400939.882440, 189.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400940.082190, 189.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400940.283176, 189.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400940.483254, 189.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400940.684468, 189.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400940.884569, 190.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400941.086534, 190.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400941.286154, 190.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400941.486258, 190.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400941.686393, 190.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400941.887272, 191.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400942.087894, 191.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400942.291525, 191.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400942.493722, 191.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400942.695845, 191.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400942.897085, 192.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400943.097489, 192.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400943.299001, 192.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400943.499600, 192.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400943.702207, 192.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400943.902534, 193.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400944.104853, 193.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400944.305052, 193.474000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400944.507202, 193.674000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400944.707315, 193.874000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400944.908131, 194.074000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [INFO] [1683400945.107907, 194.274000]: State machine transitioning 'WAIT':'wait'-->'WAIT'
# [ERROR] [1683400945.309806, 194.475000]: InvalidUserCodeError: Could not execute state 'WAIT' of type '<__main__.Wait object at 0x7fe9244bd5e0>': Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py", line 250, in _update_once
#     outcome = self._current_state.execute(
#   File "/tmp/ipykernel_4534/2759226230.py", line 13, in execute
#     rate.sleep()
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py", line 103, in sleep
#     sleep(self._remaining(curr_time))
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py", line 159, in sleep
#     rostime_cond.wait(0.5)
#   File "/usr/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:76: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return {k:v for (k, v) in self.__dict__.items() if k is not "_state_transitioning_lock"}
# /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:76: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return {k:v for (k, v) in self.__dict__.items() if k is not "_state_transitioning_lock"}
# /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:76: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return {k:v for (k, v) in self.__dict__.items() if k is not "_state_transitioning_lock"}
# /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:76: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return {k:v for (k, v) in self.__dict__.items() if k is not "_state_transitioning_lock"}
# /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:76: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return {k:v for (k, v) in self.__dict__.items() if k is not "_state_transitioning_lock"}
# /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:76: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return {k:v for (k, v) in self.__dict__.items() if k is not "_state_transitioning_lock"}
# /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:76: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return {k:v for (k, v) in self.__dict__.items() if k is not "_state_transitioning_lock"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:250, in StateMachine._update_once(self)
#     249     self._state_transitioning_lock.release()
# --> 250     outcome = self._current_state.execute(
#     251             smach.Remapper(
#     252                 self.userdata,
#     253                 self._current_state.get_registered_input_keys(),
#     254                 self._current_state.get_registered_output_keys(),
#     255                 self._remappings[self._current_label]))
#     256 except smach.InvalidUserCodeError as ex:
#
# Cell In[11], line 13, in Wait.execute(self, ud)
#      12 pub.publish(vel)
# ---> 13 rate.sleep()
#      14 if (len(puntos)) > 0:
#
# File /opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py:103, in Rate.sleep(self)
#     102 try:
# --> 103     sleep(self._remaining(curr_time))
#     104 except rospy.exceptions.ROSTimeMovedBackwardsException:
#
# File /opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py:159, in sleep(duration)
#     158     with rostime_cond:
# --> 159         rostime_cond.wait(0.5)
#     161 if rospy.rostime.get_rostime() < initial_rostime:
#
# File /usr/lib/python3.8/threading.py:306, in Condition.wait(self, timeout)
#     305 if timeout > 0:
# --> 306     gotit = waiter.acquire(True, timeout)
#     307 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# InvalidUserCodeError                      Traceback (most recent call last)
# Cell In[16], line 3
#       1 if __name__ == '__main__':
#       2     try:
# ----> 3         main()
#       4     except rospy.ROSInterruptException:
#       5         pass
#
# Cell In[15], line 23, in main()
#      20 rospy.sleep(1)
#      21 sis.start()
# ---> 23 outcome = sm.execute()
#      25 sis.stop()
#      27 rospy.sleep(1)
#
# File /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:367, in StateMachine.execute(self, parent_ud)
#     364 # Step through state machine
#     365 while container_outcome is None and self._is_running and not smach.is_shutdown():
#     366     # Update the state machine
# --> 367     container_outcome = self._update_once()
#     369 # Copy output keys
#     370 self._copy_output_keys(self.userdata, parent_ud)
#
# File /opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py:260, in StateMachine._update_once(self)
#     258     raise ex
#     259 except:
# --> 260     raise smach.InvalidUserCodeError("Could not execute state '%s' of type '%s': " %
#     261                                      (self._current_label, self._current_state)
#     262                                      + traceback.format_exc())
#     263 finally:
#     264     self._state_transitioning_lock.acquire()
#
# InvalidUserCodeError: Could not execute state 'WAIT' of type '<__main__.Wait object at 0x7fe9244bd5e0>': Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/smach/state_machine.py", line 250, in _update_once
#     outcome = self._current_state.execute(
#   File "/tmp/ipykernel_4534/2759226230.py", line 13, in execute
#     rate.sleep()
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py", line 103, in sleep
#     sleep(self._remaining(curr_time))
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py", line 159, in sleep
#     rostime_cond.wait(0.5)
#   File "/usr/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
